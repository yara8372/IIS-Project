# %%
# Created by Rahul Nimmakayala at 10:57 27-11-2021 using PyCharm

#Necessary Modules for the image classfication

import pandas
import numpy
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
import pandas as pd
...


input_path="C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v1\\course_dataset\\Landmark_Points\\annotations_a.csv"
# print(input_path)
df1=pandas.read_csv(input_path)
df2=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v1\\course_dataset\\Landmark_Points\\annotations_b.csv")
# print(df.head())


input_path=""

# %%
import pandas as pd
input_path="C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v2\\course_dataset\\ASL_letter_A\\annotations.csv"
df1=pd.read_csv(input_path)
df2=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v2\\course_dataset\\ASL_letter_B\\annotations.csv")
df3=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v2\\course_dataset\\ASL_letter_C\\annotations.csv")
df4=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v2\\course_dataset\\ASL_letter_L\\annotations.csv")
df5=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v2\\course_dataset\\ASL_letter_R\\annotations.csv")
df6=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v2\\course_dataset\\ASL_letter_U\\annotations.csv")

# %%
df3=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v1\\course_dataset\\Landmark_Points\\annotations_c.csv")
df4=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v1\\course_dataset\\Landmark_Points\\annotations_l.csv")
df5=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v1\\course_dataset\\Landmark_Points\\annotations_r.csv")
df6=pd.read_csv("C:\\Users\\Rahul R Nimmakayala\\Documents\\Uppsala-Academic\\Semester-2-P2\\Intelligent_Interactive_Systems\\Final_Project\\final_project_dataset_v1\\course_dataset\\Landmark_Points\\annotations_u.csv")

# %%
frames=[df1,df2,df3,df4,df5,df6]
df = pd.concat(frames)

# %%
df.head()
# Out:
#    ID  frame       gesture          joint  person_idx  video_idx           x  \
# 0   0      0  ASL_letter_A  hand_position      183987          0    0.000000
# 1   1      0  ASL_letter_A           root      183987          0  323.633333
# 2   2      0  ASL_letter_A        thumb_1      183987          0  266.033333
# 3   3      0  ASL_letter_A        thumb_2      183987          0  230.833333
# 4   4      0  ASL_letter_A        thumb_3      183987          0  199.900000
#
#             y
# 0    0.000000
# 1  520.750000
# 2  454.616667
# 3  445.016667
# 4  466.350000

# %%
df_A=df.drop(columns=['ID','video_idx'])
# df.groupby(['frame','person_idx']).size()
# df_test=df_A.set_index(['person_idx','frame','x','y'])

# person_id=df_A['person_idx'].unique()
df_test=df_A.pivot(values=['x','y'],index=["frame","person_idx",'gesture'],columns='joint')
# print (df_test[('x','hand_pos')])

# df.columns=pandas.MultiIndex.from_tuples(df.columns)
column_names=(df_test.columns)
# print(type(column_names))

cols_new=[]
for cols in column_names:
    tempstr=''
    for col in cols:
        tempstr=tempstr+col
    cols_new.append(tempstr)

# %%
df.head()
# Out:
#    ID  frame       gesture          joint  person_idx  video_idx           x  \
# 0   0      0  ASL_letter_A  hand_position      183987          0    0.000000
# 1   1      0  ASL_letter_A           root      183987          0  323.633333
# 2   2      0  ASL_letter_A        thumb_1      183987          0  266.033333
# 3   3      0  ASL_letter_A        thumb_2      183987          0  230.833333
# 4   4      0  ASL_letter_A        thumb_3      183987          0  199.900000
#
#             y
# 0    0.000000
# 1  520.750000
# 2  454.616667
# 3  445.016667
# 4  466.350000

# %%
df_test.head()
# Out:
#                                           x                          \
# joint                         hand_position     index_1     index_2
# frame person_idx gesture
# 0     10546      ASL_letter_A           0.0    0.000000  245.566667
#                  ASL_letter_B           0.0  316.326660  297.126660
#                  ASL_letter_C           0.0  253.393327    0.000000
#                  ASL_letter_L           0.0  124.326660   98.726660
#                  ASL_letter_R           0.0  269.606657  248.273324
#
#                                                                                \
# joint                             index_3     index_4    middle_1    middle_2
# frame person_idx gesture
# 0     10546      ASL_letter_A  269.033333  285.033333    0.000000  239.166667
#                  ASL_letter_B  281.126660  259.793327  315.259993  294.993327
#                  ASL_letter_C    0.000000  230.993327  260.859993    0.000000
# ...

# %%
cols_new
# Out:
# ['xhand_position',
#  'xindex_1',
#  'xindex_2',
#  'xindex_3',
#  'xindex_4',
#  'xmiddle_1',
#  'xmiddle_2',
#  'xmiddle_3',
#  'xmiddle_4',
#  'xpinky_1',
#  'xpinky_2',
#  'xpinky_3',
#  'xpinky_4',
#  'xring_1',
#  'xring_2',
#  'xring_3',
#  'xring_4',
#  'xroot',
#  'xthumb_1',
#  'xthumb_2',
#  'xthumb_3',
#  'yhand_position',
#  'yindex_1',
#  'yindex_2',
#  'yindex_3',
#  'yindex_4',
#  'ymiddle_1',
#  'ymiddle_2',
#  'ymiddle_3',
#  'ymiddle_4',
#  'ypinky_1',
#  'ypinky_2',
#  'ypinky_3',
#  'ypinky_4',
#  'yring_1',
#  'yring_2',
#  'yring_3',
#  'yring_4',
#  'yroot',
#  'ythumb_1',
#  'ythumb_2',
#  'ythumb_3']

# %%
temp = 0
newdf=pd.DataFrame()
newdf.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for col in column_names:
    newdf[cols_new[temp]]=df_test[col]
    temp=temp+1

# %%
newdf.head()
# Out:
#                                xhand_position    xindex_1    xindex_2  \
# frame person_idx gesture
# 0     10546      ASL_letter_A             0.0    0.000000  245.566667
#                  ASL_letter_B             0.0  316.326660  297.126660
#                  ASL_letter_C             0.0  253.393327    0.000000
#                  ASL_letter_L             0.0  124.326660   98.726660
#                  ASL_letter_R             0.0  269.606657  248.273324
#
#                                  xindex_3    xindex_4   xmiddle_1   xmiddle_2  \
# frame person_idx gesture
# 0     10546      ASL_letter_A  269.033333  285.033333    0.000000  239.166667
#                  ASL_letter_B  281.126660  259.793327  315.259993  294.993327
#                  ASL_letter_C    0.000000  230.993327  260.859993    0.000000
#                  ASL_letter_L   65.659993   37.926660    0.000000   95.526660
#                  ASL_letter_R  229.073324  207.739990  263.206657  238.673324
#
# ...

# %%
newdf=newdf.reset_index()
newdf.head()
# Out:
#    frame  person_idx       gesture  xhand_position    xindex_1    xindex_2  \
# 0      0       10546  ASL_letter_A             0.0    0.000000  245.566667
# 1      0       10546  ASL_letter_B             0.0  316.326660  297.126660
# 2      0       10546  ASL_letter_C             0.0  253.393327    0.000000
# 3      0       10546  ASL_letter_L             0.0  124.326660   98.726660
# 4      0       10546  ASL_letter_R             0.0  269.606657  248.273324
#
#      xindex_3    xindex_4   xmiddle_1   xmiddle_2  ...    ypinky_3  \
# 0  269.033333  285.033333    0.000000  239.166667  ...   67.733333
# 1  281.126660  259.793327  315.259993  294.993327  ...  146.979980
# 2    0.000000  230.993327  260.859993    0.000000  ...  526.713314
# 3   65.659993   37.926660    0.000000   95.526660  ...  576.846647
# 4  229.073324  207.739990  263.206657  238.673324  ...   96.846647
#
#      ypinky_4     yring_1     yring_2     yring_3     yring_4       yroot  \
# ...

# %%
# newdf=newdf.drop(columns=['frame','person_idx'])
newdf.head()
newdf.to_csv("IIS_combined.csv",index=False)
newdf.tail()
newdf.shape
# Out:
# (51186, 45)

# %%
y=newdf['gesture']
X=newdf.drop(columns=['gesture'])

# %%
import numpy as np

# %%
np.unique(y)
# Out:
# array(['ASL_letter_A', 'ASL_letter_B', 'ASL_letter_C', 'ASL_letter_L',
#        'ASL_letter_R', 'ASL_letter_U'], dtype=object)

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.datasets import make_classification
import numpy as np
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
clf = RandomForestClassifier(n_estimators=500,max_depth=15, random_state=0)
clf.fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 1.0

# %%
clf = AdaBoostClassifier(max_,n_estimators=500,random_state=0)

#---svm


#--svd


#-kmeans---




clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\RAHULR~1\AppData\Local\Temp/ipykernel_34236/524722783.py in <module>
#      12
#      13
# ---> 14 clf.fit(X_train, y_train)
#      15 clf.score(X_test, y_test)
#
# c:\users\rahul r nimmakayala\appdata\local\programs\python\python38\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     484
#     485         # Fit
# --> 486         return super().fit(X, y, sample_weight)
#     487
#     488     def _validate_estimator(self):
#
# c:\users\rahul r nimmakayala\appdata\local\programs\python\python38\lib\site-packages\sklearn\ensemble\_weight_boosting.py in fit(self, X, y, sample_weight)
#     143         for iboost in range(self.n_estimators):
#     144             # Boosting step
# --> 145             sample_weight, estimator_weight, estimator_error = self._boost(
# ...

# %%
#~61 old acc

# %%
newdf.shape
# Out:
# (37182, 43)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=8, random_state=0).fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.9965934558493948

# %%
# X_train.shape
print(y.shape)
# Out:
# (51186,)

# %%
y_train.head()
# Out:
# 33952    ASL_letter_L
# 30876    ASL_letter_R
# 12340    ASL_letter_U
# 7748     ASL_letter_C
# 12276    ASL_letter_A
# Name: gesture, dtype: object

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
 from sklearn.metrics import confusion_matrix

# %%
Y_pred=clf.predict(X_test)
confusion_matrix(y_test, Y_pred)
# Out:
# array([[1825,    0,    0,    0,    0,    0],
#        [   0, 1956,    0,   21,    0,    0],
#        [   0,    0, 1768,    0,    0,    0],
#        [   0,    0,    0, 1830,    0,    0],
#        [   0,    0,    0,    0, 1893,    0],
#        [  17,    0,    0,    0,    0, 1845]], dtype=int64)

# %%
from sklearn.metrics import PrecisionRecallDisplay

display = PrecisionRecallDisplay.from_estimator(
    clf, X_test, y_test, name="LinearSVC"
)
_ = display.ax_.set_title("2-class Precision-Recall curve")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\RAHULR~1\AppData\Local\Temp/ipykernel_14592/3834973148.py in <module>
#       1 from sklearn.metrics import PrecisionRecallDisplay
#       2
# ----> 3 display = PrecisionRecallDisplay.from_estimator(
#       4     clf, X_test, y_test, name="LinearSVC"
#       5 )
#
# c:\users\rahul r nimmakayala\appdata\local\programs\python\python38\lib\site-packages\sklearn\metrics\_plot\precision_recall_curve.py in from_estimator(cls, estimator, X, y, sample_weight, pos_label, response_method, name, ax, **kwargs)
#     238         if not is_classifier(estimator):
#     239             raise ValueError(f"{method_name} only supports classifiers")
# --> 240         y_pred, pos_label = _get_response(
#     241             X,
#     242             estimator,
#
# ...

# %%
from sklearn.metrics import classification_report

# %%
target_names =np.unique(y_test)
print(classification_report(y_test, Y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
# ASL_letter_A       0.99      1.00      1.00      1825
# ASL_letter_B       1.00      0.99      0.99      1977
# ASL_letter_C       1.00      1.00      1.00      1768
# ASL_letter_L       0.99      1.00      0.99      1830
# ASL_letter_R       1.00      1.00      1.00      1893
# ASL_letter_U       1.00      0.99      1.00      1862
#
#     accuracy                           1.00     11155
#    macro avg       1.00      1.00      1.00     11155
# weighted avg       1.00      1.00      1.00     11155
